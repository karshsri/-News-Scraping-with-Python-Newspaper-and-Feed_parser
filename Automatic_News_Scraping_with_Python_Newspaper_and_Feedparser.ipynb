# %% [markdown]
# <a href="https://colab.research.google.com/github/karshsri/-News-Scraping-with-Python-Newspaper-and-Feed_parser/blob/main/Automatic_News_Scraping_with_Python_Newspaper_and_Feedparser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install newspaper3k
# !pip install feedparser

# %%
# !pip install lxml_html_clean

# %%
import newspaper
import feedparser


def scrape_news_from_feed(feed_url):
    articles = []
    feed = feedparser.parse(feed_url)
    for entry in feed.entries:
        # create a newspaper article object
        article = newspaper.Article(entry.link)
        # download and parse the article
        article.download()
        article.parse()
        # extract relevant information
        articles.append({
            'title': article.title,
            'author': article.authors,
            'publish_date': article.publish_date,
            'content': article.text
        })
    return articles


feed_url = 'http://feeds.bbci.co.uk/news/rss.xml'
articles = scrape_news_from_feed(feed_url)

# print the extracted articles
for article in articles:
    print('Title:', article['title'])
    print('Author:', article['author'])
    print('Publish Date:', article['publish_date'])
    print('Content:', article['content'])
    print()
# Out:
# Title: Israel-Iran conflict set to dominate G7 summit
# Author: []
# Publish Date: None
# Content: Israel-Iran conflict set to dominate G7 summit
#
# 6 hours ago Share Save James Landale Diplomatic correspondent in Banff, Alberta Share Save
#
# Getty Images Donald Trump greets Mark Carney in May 2025.
#
# ...
